# %% [markdown]
# #Feature Engineering

# %% [markdown]
# 1.What is a parameter?
#
# ans
#
#     In Machine Learning, a parameter is an internal variable that a model learns automatically during training to make predictions.
#
#     For example, in Linear Regression, the equation is:
#     y=mx+c
#
#     Here:
#
#     𝑚 = slope → model parameter (weight)
#
#     𝑐 = intercept → model parameter (bias)
#
#     During training, the algorithm adjusts these parameters to minimize the error between predicted and actual values.
#
# 2.What is correlation?
# What does negative correlation mean?
#
# ans
#
#
#     Correlation measures the strength and direction of the relationship between two numerical variables.
#     It ranges from -1 to +1:
#
#     +1 → perfect positive correlation (both increase together)
#
#     0 → no correlation
#
#     -1 → perfect negative correlation (one increases, other decreases)
#
#     Example:
#
#     X	Y
#     1	2
#     2	4
#     3	6
#
#     Here, X and Y have a correlation of +1 (perfectly proportional).
#
#     A negative correlation means that when one variable increases, the other tends to decrease.
#     Example:
#
#     Number of hours spent watching TV vs. Exam scores.
#     As TV hours increase, exam scores usually decrease — this indicates a negative correlation.
#
# 3.Define Machine Learning. What are the main components in Machine Learning?
#
# ans
#
#     Machine Learning (ML) is a branch of Artificial Intelligence that allows systems to learn from data and make predictions without explicit programming.
#
#     Main components:
#
#     Data – Input data used for training.
#
#     Model – Mathematical representation of the relationship in data.
#
#     Loss function – Measures how far predictions are from true values.
#
#     Optimizer – Adjusts model parameters to minimize loss.
#
#     Training process – The process of learning from data.
#
#     Evaluation – Assessing model performance on unseen data.
#
# 4.How does loss value help in determining whether the model is good or not?
#
# ans
#
#
#     The loss value (or cost) measures the difference between predicted and actual values.
#
#     Low loss → better model performance.
#
#     High loss → poor predictions.
#     In training, the optimizer tries to minimize this loss.
#
#     Example (Regression):
#
#     Loss=n1∑(ypred−yactual)2
#
# 5.What are continuous and categorical variables?
#
# ans
#
#     Continuous variables: Can take infinite numeric values within a range.
#     Example: Height, weight, temperature.
#
#     Categorical variables: Represent discrete categories or groups.
#     Example: Gender (Male/Female), City (Delhi, Mumbai).
#
# 6.How do we handle categorical variables in Machine Learning? What are the common techniques?
#
# ans
#
#
#     Categorical data must be converted into numbers before feeding into ML models.
#
#     Common techniques:
#
#     Label Encoding – Assigns each category a unique number.
#     Example: {'Male': 0, 'Female': 1}
#
#     One-Hot Encoding – Creates binary columns for each category.
#     Example: {'Red': [1,0,0], 'Blue': [0,1,0], 'Green': [0,0,1]}
#
#     Ordinal Encoding – Used when categories have order.
#     Example: {'Low': 1, 'Medium': 2, 'High': 3}
#
# 7.What do you mean by training and testing a dataset?
#
# ans
#
#
#     Training dataset: Used to train the model (learn patterns).
#
#     Testing dataset: Used to evaluate model performance on unseen data.
#
#     Example:
#     from sklearn.model_selection import train_test_split
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#
# 8.What is sklearn.preprocessing?
#
# ans
#
#     sklearn.preprocessing is a module in Scikit-learn that provides tools for:
#
#     Scaling numerical data.
#
#     Encoding categorical data.
#
#     Normalization and imputation of missing values.
#
#     Example:
#     from sklearn.preprocessing import StandardScaler, OneHotEncoder
#
# 9.What is a Test set?
#
# ans
#
#     A test set is a portion of the dataset reserved for evaluating how well the trained model performs on unseen data.
#     It helps detect overfitting.
#
# 10.How do we split data for model fitting (training and testing) in Python?
# How do you approach a machine learning problem?
#
# ans
#
#     Using train_test_split from sklearn.model_selection:
#
#     from sklearn.model_selection import train_test_split
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
#
#     test_size=0.3 → 30% data used for testing
#
#     random_state → ensures reproducibility
#
#   approaching a machine Learning problem
#
#     Step-by-step approach:
#
#     Understand the problem – Define objective & success metric.
#
#     Collect and explore data (EDA).
#
#     Data preprocessing – Handle missing values, encode categories.
#
#     Feature engineering – Create or modify features.
#
#     Split data – Training & testing sets.
#
#     Select model – Choose algorithm (e.g., regression, decision tree).
#
#     Train model – Fit model to training data.
#
#     Evaluate – Use metrics (accuracy, RMSE, etc.)
#
#     Tune parameters – Optimize model performance.
#
#     Deploy & monitor – Use model in real-world scenario.
#
# 11.Why do we have to perform EDA before fitting a model to the data?
#
# ans
#
#     EDA (Exploratory Data Analysis) helps to:
#
#     Understand data structure.
#
#     Detect outliers or missing values.
#
#     Identify relationships between features.
#
#     Choose appropriate preprocessing and models.
#
#     Without EDA, models may be trained on dirty or biased data.
#
#
#
# 12.What is correlation?
#
# ans
#
#     Correlation measures the strength and direction of the relationship between two numerical variables.
#     It ranges from -1 to +1:
#
#     +1 → perfect positive correlation (both increase together)
#
#     0 → no correlation
#
#     -1 → perfect negative correlation (one increases, other decreases)
#
#     Example:
#
#      X	Y
#      1	2
#      2	4
#      3	6
#
#     Here, X and Y have a correlation of +1 (perfectly proportional).
#
# 13.What does negative correlation mean?
#
# ans
#
#     A negative correlation means that when one variable increases, the other tends to decrease.
#     Example:
#
#     Number of hours spent watching TV vs. Exam scores.
#     As TV hours increase, exam scores usually decrease — this indicates a negative correlation.
#
# 14.How can you find correlation between variables in Python?
#
#  ans
#
#     Using Pandas:
#     import pandas as pd
#     df.corr()
#     or
#     visualize:
#     import seaborn as sns
#     sns.heatmap(df.corr(), annot=True)
#
# 15.What is causation? Explain difference between correlation and causation with an example.
#
#  ans
#
#     Causation: When one variable directly influences another.
#
#     Correlation: Only shows a relationship, not cause and effect.
#
#     Example:
#
#     Ice cream sales and drowning cases are correlated (both rise in summer).
#     → But ice cream does not cause drowning → correlation ≠ causation.
#
#
# 16.What is an Optimizer? What are different types of optimizers?
#
# ans
#
#     An optimizer updates the model parameters to reduce loss during training.
#
#     Common types:
#
#     Gradient Descent – Updates weights using gradient of loss.
#
#     Stochastic Gradient Descent (SGD) – Updates weights per sample.
#
#     Momentum – Adds past gradient for faster convergence.
#
#     Adam – Adaptive learning rate + momentum (most popular).
#
#     Example:
#
#     optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
#
# 17.What is sklearn.linear_model ?
#
# ans
#
#     A module in Scikit-learn containing linear models such as:
#
#     LinearRegression
#
#     LogisticRegression
#
#     Ridge, Lasso, etc.
#
#     Example:
#
#     from sklearn.linear_model import LinearRegression
#     model = LinearRegression()
#
# 18.What does model.fit() do? What arguments must be given?
#
#  ans
#
#     model.fit(X, y) trains the model using input features X and target labels y.
#     It learns the parameters (weights and bias).
#
#     Example:
#
#     model.fit(X_train, y_train)
#
# 19.What does model.predict() do? What arguments must be given?
#
# ans
#
#     model.predict(X) uses the trained model to predict outputs for new data.
#
#     Example:
#
#     predictions = model.predict(X_test)
#
#
#
# 20.What are continuous and categorical variables?
#
# ans
#
#     Continuous variables: Can take infinite numeric values within a range.
#     Example: Height, weight, temperature.
#
#     Categorical variables: Represent discrete categories or groups.
#     Example: Gender (Male/Female), City (Delhi, Mumbai).
#
# 21.What is feature scaling? How does it help in Machine Learning?
#
# ans
#
#     Feature scaling standardizes numerical data into a specific range so that no feature dominates others.
#
#     Helps when:
#
#     Features have different units/scales.
#
#     Algorithms like SVM, KNN, Gradient Descent are used.
#
# 22.How do we perform scaling in Python?
#
# ans
#
#     Using StandardScaler or MinMaxScaler from sklearn.preprocessing.
#
#     Example:
#
#     from sklearn.preprocessing import StandardScaler
#     scaler = StandardScaler()
#     X_scaled = scaler.fit_transform(X)
#
# 23.What is sklearn.preprocessing?
#
# ans
#
#     sklearn.preprocessing is a module in Scikit-learn that provides tools for:
#
#     Scaling numerical data.
#
#     Encoding categorical data.
#
#     Normalization and imputation of missing values.
#
#     Example:
#
#     from sklearn.preprocessing import StandardScaler, OneHotEncoder
#
# 24.How do we split data for model fitting (training and testing) in Python?
#
# ans
#
#     Using train_test_split from sklearn.model_selection:
#
#     from sklearn.model_selection import train_test_split
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
#
#     test_size=0.3 → 30% data used for testing
#
#     random_state → ensures reproducibility
#
# 25.Explain data encoding.
#
# ans
#
#     Data encoding is the process of converting categorical data into numerical format so ML models can understand it.
#
#     Types:
#
#     Label Encoding
#
#     One-Hot Encoding
#
#     Binary Encoding
#
#     Frequency Encoding
#
#     Example:
#
#     from sklearn.preprocessing import OneHotEncoder
#     encoder = OneHotEncoder()
#     X_encoded = encoder.fit_transform(X[['Category']])
